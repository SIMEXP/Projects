# %% [markdown]
# Figures we need:
# - similarity matrix of the somato-motor network
# - model matrix of the noise regression GLM
# - sorted weight matrices for the somato-motor network
# - raw (non-regressed) seed maps for individuals from one cluster
# - the corresponding regressed seed maps for these individuals
# - a nice representation of the somato-motor network
#
# Regarding the maps:
#
# If this doesn't look good enough with the nilearn plotting options, then we can also use MRIcroGL.

# %%
# Imports
import os
import glob
import numpy as np
import pandas as pd
#import seaborn as sb
import brainbox as bb
import nibabel as nib
import nilearn as nil
from scipy import io as sio
from matplotlib import gridspec
from nilearn import plotting as nlp
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
# Network name lookup table
sc7_names = [
             'Cerebellum',
             'Limbic',
             'Somatomotor',
             'Visual',
             'Default Mode',
             'Frontoparietal',
             'Ventral Attention'
            ]
sc12_names = [
              'Basal Ganglia',
              'Auditory',
              'Limbic',
              'Lateral Default Mode',
              'Visual',
              'Posterior medial Default Mode',
              'Somatomotor',
              'Anterior Default Mode',
              'Higher Visual',
              'Frontoparietal',
              'Ventral Attention',
              'Cerebellum'
              ]

# %%
# Paths
somatomotor_path = '/data1/guilimin/data/abide/HBM2016/sc7/full_maybe/network_3/'
subtype_path = 'network_3_subtype.mat'
stack_path = 'network_3_stack.mat'
model_path = '/data1/guilimin/data/abide/pheno/sc7/model_full_maybe_sc7.csv'
mas_path = '/data1/guilimin/data/abide/masks/template_mask.nii.gz'

#figure_path = '/home/surchs/GDrive/PhD/Conferences/HBM2016/Poster/Figures/'
figure_path = '/home/surchs/GDrive/PhD/Conferences/MIICIA2016/Figures'

# %%
m_img = nib.load(mas_path)
mask = m_img.get_data().astype(bool)
m_vec = np.reshape(mask, np.prod(mask.shape), order='F')

# %% [markdown]
# ## Similarity Matrix

# %%
submat = sio.loadmat(os.path.join(somatomotor_path, subtype_path))

# %%
# Make the map
simmat = submat['sim_matrix']
order = submat['subj_order']
order = np.array([np.int(x) for x in order], dtype=int)

part = submat['part']
part_ord = part[order-1]
show_mat = simmat[order-1, :][:, order-1]

part_frame = np.zeros(simmat.shape)

for sbt_id in np.arange(5):
    # Get first and last element
    hits = np.where(part_ord==sbt_id+1)[0]
    first = hits[0]
    last = hits[-1]
    if first > 1:
        # We can probably go back 4
        frontup = (first-3, first-2, first-1, first)
        selstart = first-3
    else:
        frontup = (first,)
        selstart = first
    if last < part_frame.shape[0] - 3:
        # we can probably extend 4
        backtup = (last, last+1, last+2, last+3)
        selstop = last+3
    else:
        backtup = (last,)
        selstop = last
    # Draw column
    devtuple = frontup + backtup
    part_frame[selstart:selstop, devtuple] = 1
    # Draw rows 
    part_frame[devtuple, selstart:selstop] = 1
part_frame = np.ma.masked_where(part_frame == 0, part_frame)

fig = plt.figure(figsize=(12,12))
gs = gridspec.GridSpec(1, 20, hspace=0)
ax_1 = fig.add_subplot(gs[0, :-1])
tmp = ax_1.matshow(show_mat, vmin=-0.2, vmax=0.2, cmap=bb.visu.hot_cold())
ax_1.set_xticklabels([])
ax_1.set_yticklabels([])

ax_2 = fig.add_subplot(gs[0, -1])
plt.colorbar(tmp, cax=ax_2)

fig_name = 'somatomotor_simmat_nolines.png'
fig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
            pad_inches=0)

"""
ax_1.matshow(part_frame, cmap=plt.cm.Greys, alpha=1)
ax_1.set_xticklabels([])
ax_1.set_yticklabels([])

fig_name = 'somatomotor_simmat_lines.png'
fig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
            pad_inches=0)
"""
# Out:
# "\nax_1.matshow(part_frame, cmap=plt.cm.Greys, alpha=1)\nax_1.set_xticklabels([])\nax_1.set_yticklabels([])\n\nfig_name = 'somatomotor_simmat_lines.png'\nfig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',\n            pad_inches=0)\n"

# %%
# Show the noise regression model
model = pd.read_csv(model_path)
tmp = model
tmp.rename(columns={'SUB_ID': 'Intercept'}, inplace=True)
tmp['Intercept'] = np.ones(tmp.shape[0])
# Normalize stuff
tmp.AGE_AT_SCAN = (tmp.AGE_AT_SCAN - np.mean(tmp.AGE_AT_SCAN))/np.std(tmp.AGE_AT_SCAN)
tmp.FD_scrubbed = (tmp.FD_scrubbed - np.mean(tmp.FD_scrubbed))/np.std(tmp.FD_scrubbed)
#tmp.DX_GROUP.replace({2:0}, inplace=True)
tmp.drop('DX_GROUP', axis=1, inplace=True)

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111)
ax.matshow(tmp.as_matrix(), cmap=plt.cm.Greys, aspect='auto')
ax.set_xticks([])
ax.set_yticks([])
fig_name = 'noise_model_matrix.png'
fig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
            pad_inches=0)

# %%
# Show some uncorrected maps and then the corresponding corrected maps
order = submat['subj_order']
order = np.array([np.int(x) for x in order], dtype=int)
part = submat['part']
# Get some subjects from subtype 2 and some from subtype 3 for contrast
sbt2 = np.where(part==2)[0]
sbt3 = np.where(part==3)[0]

# %%
# Show the subtype maps for the somatomotor network
sbt = sio.loadmat('/data1/guilimin/data/abide/HBM2016/sc7/full_maybe/network_3/network_3_subtype.mat')
ns = sio.loadmat('/data1/guilimin/data/abide/HBM2016/sc7/full_maybe/network_3/network_3_stack.mat')
stack = ns['stack']
part = submat['part'].flatten()
m_vec = np.reshape(mask, np.prod(mask.shape), order='F')

for subtype in np.arange(5)+1:
    tmp = np.zeros_like(m_vec, dtype=float)
    tmp[m_vec] = np.mean(stack[part==subtype, :],0)/np.std(stack[part==subtype, :])
    tmp = np.reshape(tmp, mask.shape, order='F')

    s_img = nib.Nifti1Image(tmp, header=m_img.get_header(), affine=m_img.get_affine())
    fig = plt.figure(figsize=(18,6))
    ax = fig.add_subplot(111)
    nlp.plot_stat_map(s_img, display_mode='ortho', threshold=0, annotate=False, cmap=bb.visu.hot_cold(),
                      black_bg=False,axes=ax, colorbar=False, draw_cross=False, cut_coords=(9,-24,48))
    
    s_name = 'net_3_subtype_{}_map_norm.png'.format(subtype)
    fig.savefig(os.path.join(figure_path, s_name), transparent=False, bbox_inches='tight',
            pad_inches=0)
    
    
    figx = plt.figure(figsize=(6,6))
    ax = figx.add_subplot(111)
    nlp.plot_stat_map(s_img, display_mode='x', threshold=0, annotate=False, cut_coords=[9], cmap=bb.visu.hot_cold(),
                      black_bg=False,axes=ax, colorbar=False, draw_cross=False)
    
    s_name = 'x_net_3_subtype_{}_map_norm.png'.format(subtype)
    figx.savefig(os.path.join(figure_path, s_name), transparent=False, bbox_inches='tight', pad_inches=0)

# %%
# Now show the raw images
model = pd.read_csv(model_path)
seed_tmp = '/data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_{:07}_session_*_run*.nii.gz'

raw_stack = np.zeros((model.shape[0], np.sum(mask)))
for ind, row in model.iterrows():
    s_name = 'sub_{:07}'.format(row.SUB_ID.astype(int))
    p = glob.glob(seed_tmp.format(row.SUB_ID.astype(int)))[0]
    t = nib.load(p)
    # Get network 3
    d = t.get_data()[..., 2]
    # mask it
    md = d[mask]
    raw_stack[ind, ...] = md
# Out:
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051459_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051465_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051467_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051473_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051474_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051484_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051485_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051486_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051487_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051488_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050772_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050774_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050776_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050777_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050779_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050782_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050785_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050786_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050787_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050789_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050791_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050793_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050794_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050797_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050799_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050800_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050801_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050802_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050803_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050804_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050805_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050806_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050807_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050809_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050813_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050814_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050815_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050816_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050818_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050819_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050821_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050822_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050823_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050824_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050825_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050826_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050682_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050683_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050685_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050686_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050687_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050690_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050691_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050692_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050693_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050694_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050695_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050696_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050697_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050698_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050699_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050700_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050704_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050705_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050706_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050707_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050708_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050709_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051318_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051322_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051323_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051324_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051328_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051331_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051333_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051335_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051336_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051347_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051350_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051351_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051352_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051353_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051358_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051359_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051361_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051362_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051364_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051369_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051373_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051607_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050964_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050965_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050966_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050967_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050971_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050972_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050973_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050974_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050975_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050976_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050977_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050978_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050979_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050980_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050981_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050982_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050983_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050984_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050985_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050986_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050987_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050988_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050989_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050990_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050992_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050993_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050994_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050995_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050996_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050997_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050998_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050999_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051000_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051001_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051002_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051003_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051008_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051009_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051010_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051011_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051012_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051013_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051015_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051017_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051018_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051019_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051020_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051021_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051023_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051025_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051026_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051027_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051028_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051029_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051032_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051033_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051034_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051035_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051064_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051065_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051067_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051068_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051069_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051070_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051071_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051072_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051073_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051074_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051075_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051077_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051078_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051079_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051080_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051081_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051082_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051083_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051084_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051085_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051086_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051087_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051088_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051089_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051090_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051091_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051093_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051094_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051095_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051096_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051097_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051098_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051099_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051100_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051101_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051102_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051103_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051107_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051108_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051109_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051112_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051114_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051115_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051116_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051120_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051121_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051122_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051123_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051126_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051128_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051129_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051146_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051151_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051152_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051153_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051154_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051156_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051159_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050144_session_1_run3.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050145_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050146_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050147_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050150_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050152_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050153_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050158_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050159_session_1_run3.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050163_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050166_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050167_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050168_session_1_run2.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050170_session_1_run3.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050103_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050105_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050107_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050108_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050110_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050111_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050112_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050118_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050120_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050123_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050126_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050131_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050132_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050135_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050002_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050003_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050004_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050006_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050007_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050009_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050011_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050013_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050014_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050016_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050017_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050019_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050020_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050022_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050024_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050026_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050027_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050030_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050031_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050032_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050034_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050035_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050037_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050040_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050041_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050042_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050043_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050044_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050045_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050046_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050047_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050048_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050050_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050051_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050053_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050054_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050056_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050060_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051556_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051557_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051559_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051560_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051562_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051563_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051565_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051566_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051567_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051573_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051574_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051575_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051577_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051579_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051580_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051582_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051583_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051585_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050182_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050186_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050189_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050190_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050191_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050195_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050199_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050200_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050202_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050207_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050209_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050210_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050211_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050216_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051169_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051175_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051177_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051178_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051186_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051189_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051196_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051198_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050232_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050234_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050235_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050236_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050237_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050238_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050239_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050240_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050241_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050242_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050243_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050246_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050247_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050248_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050249_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050250_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050253_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050254_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050259_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050260_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050261_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050262_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050263_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050264_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050265_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050267_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050268_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050269_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050270_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051132_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051133_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051135_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051137_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051139_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051140_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051141_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051202_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051203_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051205_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051206_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051208_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051209_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051210_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051211_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051212_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051214_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051216_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051217_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051218_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051221_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051222_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051223_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051229_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051231_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051234_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051235_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051236_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051237_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051240_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051241_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051250_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051251_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051252_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051253_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051254_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051255_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051256_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051257_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051258_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051259_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051260_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051261_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051262_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051263_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051265_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051268_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051269_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051271_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051272_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051273_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051276_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051277_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051278_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051281_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051293_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051294_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051298_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051299_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051302_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051306_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051307_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051309_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051312_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051314_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051315_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0051317_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050272_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050273_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050274_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050275_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050277_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050279_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050280_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050281_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050282_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050283_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050286_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050287_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050290_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050291_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050296_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050298_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050301_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050304_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050306_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050310_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050314_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050318_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050324_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050325_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050326_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050328_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050331_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050333_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050334_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050335_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050337_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050339_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050345_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050347_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050349_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050355_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050358_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050359_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050360_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050363_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050364_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050365_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050366_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050367_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050368_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050371_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050372_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050376_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050378_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050381_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050433_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050434_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050435_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050437_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050438_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050439_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050440_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050441_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050442_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050443_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050444_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050445_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050446_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050447_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050448_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050449_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050450_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050451_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050452_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050453_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050454_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050455_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050456_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050457_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050459_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050460_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050461_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050462_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050463_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050464_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050466_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050467_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050468_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050469_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050470_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050471_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050472_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050473_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050474_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050476_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050477_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050482_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050483_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050484_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050485_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050486_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050487_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050489_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050491_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050493_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050494_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050495_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050497_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050498_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050499_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050500_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050501_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050502_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050503_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050504_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050505_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050506_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050509_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050511_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050512_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050513_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050517_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050518_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050519_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050520_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050522_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050523_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050524_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050525_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050526_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050528_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050530_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050532_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050552_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050553_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050559_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050560_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050561_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050562_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050564_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050567_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050568_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050570_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050571_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050573_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050574_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050575_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050577_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050578_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050601_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050602_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050603_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050606_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050607_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050608_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050609_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050611_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050612_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050614_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050616_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050617_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050618_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050622_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050626_session_1_run1.nii.gz
# Loading /data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_0050628_session_1_run1.nii.gz

# %%
# Regenerate the subtype maps
for sbt_id in np.arange(5)+1:
    sbt_ind = np.where(part==sbt_id)[0]
    sbt_maps = raw_stack[sbt_ind, :]
    sbt_map = np.mean(sbt_maps,0)
    # Bring it back to volume level
    tmp = np.zeros_like(mask, dtype=np.float)
    tmp[mask] = sbt_map
    sbt_img = nib.Nifti1Image(tmp, header=m_img.get_header(), affine=m_img.get_affine())
    out_path = os.path.join(figure_path, 'raw_sbt_map_net3_sbt_{}.nii.gz'.format(sbt_id))
    nib.save(sbt_img, out_path)
    
    fig = plt.figure(figsize=(18,6))
    ax = fig.add_subplot(111)
    nlp.plot_stat_map(sbt_img, threshold=0, annotate=False, cmap=bb.visu.hot_cold(),
                      black_bg=False, axes=ax, colorbar=False, draw_cross=False, vmax=1,
                     cut_coords=(9,-24,48))
    fig_name = 'raw_net_3_sbt_{}.png'.format(sbt_id)
    fig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
                pad_inches=0)
    
    figx = plt.figure(figsize=(6,6))
    ax = figx.add_subplot(111)
    nlp.plot_stat_map(sbt_img, display_mode='x', threshold=0, annotate=False, cut_coords=[9], cmap=bb.visu.hot_cold(),
                      black_bg=False,axes=ax, colorbar=False, draw_cross=False, vmax=1)
    fig_name = 'x_raw_net_3_sbt_{}.png'.format(sbt_id)
    figx.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
                pad_inches=0)

# %%
# Get the global average signal
g_avg = np.mean(raw_stack,0)
g_avg_vol = np.zeros_like(mask, dtype=np.float)
g_avg_vol[mask] = g_avg
g_avg_img = nib.Nifti1Image(g_avg_vol, header=m_img.get_header(), affine=m_img.get_affine())

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(111)
nlp.plot_stat_map(g_avg_img, threshold=0, annotate=False, cmap=bb.visu.hot_cold(),
                  black_bg=False, axes=ax, colorbar=False, draw_cross=False, vmax=1,
                 cut_coords=(9,-24,48))

fig_name = 'raw_global_avg_net_3_sbt_{}.png'.format(sbt_id)
fig.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
            pad_inches=0)

# %%
# Now show the raw images
model = pd.read_csv(model_path)
seed_tmp = '/data1/guilimin/data/abide/netstack/sca_z/sc7//netstack_fmri_{:07}_session_1_run1.nii.gz'
for sbt_id in np.arange(5)+1:
    sbt_ind = np.where(part==sbt_id)[0]
    sub_path = os.path.join(figure_path, 'sub{}'.format(sbt_id))
    if not os.path.isdir(sub_path):
        os.makedirs(sub_path)
    for ids in np.arange(7):
        s_name = 'sub_{:07}'.format(model.iloc[sbt_ind[ids]].SUB_ID.astype(int))
        t = nib.load(seed_tmp.format(model.iloc[sbt_ind[ids]].SUB_ID.astype(int)))

        fig = plt.figure(figsize=(18,6))
        ax = fig.add_subplot(111)
        nlp.plot_stat_map(nil.image.index_img(t, 2), threshold=0, annotate=False, cmap=bb.visu.hot_cold(),
                          black_bg=False,axes=ax, colorbar=True, draw_cross=False, vmax=1,
                         cut_coords=(9,-24,48))
        fig_name = 'raw_{}_net_3_sbt_{}_nc.png'.format(s_name, sbt_id)
        #fig.savefig(os.path.join(sub_path ,fig_name), transparent=False, bbox_inches='tight',
        #            pad_inches=0)
        
        fig = plt.figure(figsize=(6,6))
        ax = fig.add_subplot(111)
        nlp.plot_stat_map(nil.image.index_img(t, 2), display_mode='x', threshold=0, annotate=False, cut_coords=[9],
                          black_bg=False,axes=ax, colorbar=True, draw_cross=False, cmap=bb.visu.hot_cold())
        fig_name = 'x_raw_{}_net_3_sbt_{}.png'.format(s_name, sbt_id)
        #fig.savefig(os.path.join(sub_path ,fig_name), transparent=False, bbox_inches='tight',
        #            pad_inches=0)
        break

        plt.close()

# %%
# Get the network stack
m_img = nib.load(mas_path)
mask = m_img.get_data().astype(bool)
m_vec = np.reshape(mask, np.prod(mask.shape), order='F')

model = pd.read_csv(model_path)
seed_tmp = '/data1/guilimin/data/abide/netstack/sca_z/sc7/netstack_fmri_{:07}_session_1_run1.nii.gz'

m_vec = np.reshape(mask, np.prod(mask.shape), order='F')
ns = sio.loadmat('/data1/guilimin/data/abide/HBM2016/sc7/full_maybe/network_3/network_3_stack.mat')
stack = ns['stack']

for sbt_id in [2]:#np.arange(5)+1:
    sbt_ind = np.where(part==sbt_id)[0]
    sub_path = os.path.join(figure_path, 'sub{}'.format(sbt_id))
    if not os.path.isdir(sub_path):
        os.makedirs(sub_path)
    for ids in np.arange(7):

        s_num = model
        s2_name = 'sub_{:07}'.format(model.iloc[sbt_ind[ids]].SUB_ID.astype(int))

        tmp2 = np.zeros_like(m_vec, dtype=float)
        tmp2[m_vec] = stack[sbt_ind[ids], :]
        tmp2 = np.reshape(tmp2, mask.shape, order='F')
        s2_img = nib.Nifti1Image(tmp2, header=m_img.get_header(), affine=m_img.get_affine())

        fig_2 = plt.figure(figsize=(18,6))
        ax = fig_2.add_subplot(111)
        nlp.plot_stat_map(s2_img, display_mode='ortho', threshold=0, annotate=False, cmap=bb.visu.hot_cold(),
                          black_bg=False,axes=ax, colorbar=False, draw_cross=False,
                         cut_coords=(9,-24,48))
        fig2_name = 'regressed_{}_net_3_sbt_{}.png'.format(s2_name, sbt_id)
        fig_2.savefig(os.path.join(sub_path, fig2_name), transparent=False, bbox_inches='tight',
                pad_inches=0)

        fig_2x = plt.figure(figsize=(6,6))
        ax = fig_2x.add_subplot(111)
        nlp.plot_stat_map(s2_img, display_mode='x', threshold=0, annotate=False, cut_coords=[9],
                          black_bg=False,axes=ax, colorbar=False,  cmap=bb.visu.hot_cold())
        fig2x_name = 'x_regressed_{}_net_3_sbt_{}.png'.format(s2_name, sbt_id)
        fig_2x.savefig(os.path.join(sub_path, fig2x_name), transparent=False, bbox_inches='tight',
                pad_inches=0)

        plt.close()

# %%
# Get the weight matrix
weight_path = '/data1/guilimin/data/abide/HBM2016/sc7/full_maybe/sbt_weights_net_3.csv'
weights = pd.read_csv(weight_path)
weights.rename(columns={' ':'SUB_ID'}, inplace=True)
weights.columns = weights.columns.str.strip(' ')
weights.SUB_ID = weights.SUB_ID.str.extract('(?<=sub_)(\d+)').astype(int)
w = weights[['sub1', 'sub2', 'sub3', 'sub4', 'sub5']].as_matrix()
w_ord = w[order-1, :]
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:6: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
f = plt.figure(figsize=(6,12))
ax = f.add_subplot(111)
tmp = ax.matshow(w_ord, aspect='auto', cmap=bb.visu.hot_cold(), vmin=-0.8, vmax=0.8)
ax.set_xticklabels([])
ax.set_yticklabels([])
fig_name = 'weight_mat_net3.svg'
f.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
          pad_inches=0)

# %%
f = plt.figure(figsize=(6,6))
ax = f.add_subplot(111)
tmp = ax.matshow(w_ord, aspect='auto', cmap=bb.visu.hot_cold(), vmin=-0.8, vmax=0.8)
ax.set_xticklabels([])
ax.set_yticklabels([])
fig_name = 'weight_mat_net3_short.svg'
f.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
          pad_inches=0)
fig_name = 'weight_mat_net3_short.png'
f.savefig(os.path.join(figure_path, fig_name), transparent=False, bbox_inches='tight',
          pad_inches=0)
