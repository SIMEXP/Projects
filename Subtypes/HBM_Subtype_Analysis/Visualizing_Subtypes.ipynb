# %% [markdown]
# # Visualize subtypes @ scale 7
# The main purpose is to get a quick overview of the distribution of connectivity patterns. I will focus on diagnosis first and then take a look at SRS.

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn as nil
from matplotlib import gridspec
from nilearn import plotting as nlp
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
# Let's start with the full sample, maybe data, mean subtype at scale 7. We look at everything
res_path = '/data1/guilimin/abide/subtype/sc7/full_maybe_median/network_{}/'
mod_path = '/data1/guilimin/abide/pheno/sc7/model_full_maybe_sc7.csv'

# %%
mod = pd.read_csv(mod_path)

# %%
# Plot the first subtype
res_img = nib.load(os.path.join(res_path.format(network), 'mean_subtype.nii.gz'))
gav_img = nib.load(os.path.join(res_path, 'grand_mean.nii.gz'))

# %%
data = res_img.get_data()

# %%
data.shape
# Out:
# (53, 64, 52, 5)

# %%
network = 2

res_img = nib.load(os.path.join(res_path.format(network), 'mean_subtype.nii.gz'))

fig = plt.figure(figsize=(15,20))
gs = gridspec.GridSpec(6, 1, hspace=0)
axo = fig.add_subplot(gs[0,0])
nlp.plot_stat_map(gav_img, display_mode='x', alpha=0.9,
                  cut_coords=np.arange(-10,70,15), black_bg=True, axes=axo)
# Show the average map
for sbt_id in np.arange(5):
    axi = fig.add_subplot(gs[net_id+1,0])
    tmp = nlp.plot_stat_map(nil.image.index_img(res_img, sbt_id), display_mode='x', alpha=0.9,
                      cut_coords=np.arange(-10,70,15), black_bg=True, axes=axi)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-cb82d2482f7e> in <module>()
#       1 network = 2
#       2
# ----> 3 res_img = nib.load(os.path.join(res_path.format(network), 'mean_subtype.nii.gz'))
#       4
#       5 fig = plt.figure(figsize=(15,20))
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      42        Image of guessed type
#      43     '''
# ---> 44     return guessed_image_type(filename).from_filename(filename, **kwargs)
#      45
#      46
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/nibabel/loadsave.py in guessed_image_type(filename)
#      74             klass = Minc2Image if signature == b'\211HDF' else Minc1Image
#      75     elif lext == '.nii':
# ---> 76         with BinOpener(filename) as fobj:
#      77             binaryblock = fobj.read(348)
#      78         ft = which_analyze_type(binaryblock)
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/nibabel/openers.py in __init__(self, fileish, *args, **kwargs)
#     118         if 'compresslevel' in arg_names and 'compresslevel' not in kwargs:
#     119             kwargs['compresslevel'] = self.default_compresslevel
# --> 120         self.fobj = opener(fileish, *args, **kwargs)
#     121         self._name = fileish
#     122         self.me_opened = True
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/nibabel/openers.py in _gzip_open(fileish, *args, **kwargs)
#      61
#      62 def _gzip_open(fileish, *args, **kwargs):
# ---> 63     gzip_file = BufferedGzipFile(fileish, *args, **kwargs)
#      64
#      65     # Speedup for #209; attribute not present in in Python 3.5
#
# /usr/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#     165             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data1/guilimin/abide/subtype/sc7/full_maybe_median/network_2/mean_subtype.nii.gz'
