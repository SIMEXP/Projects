# %%
import numpy as np
import pandas as pd

# %%
pheno = '/data1/abide/Pheno/ados_pheno.csv'

# %%
p = pd.read_csv(pheno)

# %%
p
# Out:
#      SITE_ID  SUB_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX  \
# 0    CALTECH   51456         1          4      55.4000    1
# 1    CALTECH   51457         1          4      22.9000    1
# 2    CALTECH   51458         1          1      39.2000    1
# 3    CALTECH   51459         1          1      22.8000    1
# 4    CALTECH   51460         1          1      34.6000    2
# 5    CALTECH   51462         1          1      20.2000    2
# 6    CALTECH   51463         1          1      20.2000    2
# 7    CALTECH   51465         1          1      20.2000    1
# 8    CALTECH   51466         1          1      27.6000    1
# 9    CALTECH   51468         1          1      20.1000    1
# 10   CALTECH   51469         1          4      45.1000    1
# 11   CALTECH   51470         1          4      29.1000    1
# 12   CALTECH   51472         1          1      17.5000    1
# 13   CALTECH   51474         1          1      20.9000    1
# 14       KKI   50793         1          1       8.4000    1
# ...
